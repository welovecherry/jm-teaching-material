# %% [markdown]
# # 1.5과목 · 파이썬 브릿지 — 1층 연습장 (딕셔너리 1개)
#
# 이 노트북은 **직접 쳐보는 연습장**입니다. 개념 설명과 정답은 교재(MkDocs)에 있습니다.
#
# - 교재: `파이썬 브릿지 1층 · 딕셔너리` 페이지
# - 사용법: **빈 코드 칸에 직접** 답을 쳐서 실행합니다. 막히면 교재의 `▶ 정답 보기`를 펼칩니다.
# - 문제 번호는 교재와 **똑같이** 맞췄습니다 (1-1 ~ 1-9).
#
# > **왜 노트북과 교재를 나눴나?** 노트북은 '손으로 치는' 근육을, 교재는 '읽고 이해하는' 눈을 훈련합니다. 섞으면 둘 다 흐려집니다.

# %% [markdown]
# ## 0. 워밍업 — 딕셔너리 만들고 꺼내기
#
# 아래 칸을 **그대로 실행**해 보세요. 1층 전체가 이 상자 하나에서 출발합니다.

# %%
# 직원 한 명의 정보를 상자(딕셔너리) 하나에 담습니다
user = {"name": "kim01", "dept": "finance", "level": "read"}

print(user)          # 상자 전체
print(user["name"])  # 이름표 name 의 값

# %% [markdown]
# ---
# ### ✍️ 문제 1-1. 부서(시스템) 꺼내기
#
# **설명**
# 요청한 사람이 접근하려는 시스템 이름을 출력하세요.
#
# **만들 것**
# system 값을 출력하는 한 줄
#
# **나와야 하는 결과**
# ```
# finance_system
# ```
#
# > 정답과 해설은 교재의 같은 번호에서 확인하세요.

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)
request = {"id": "req-1001", "user": "kim01", "system": "finance_system", "status": "requested"}

# 여기에 직접 작성 👇

# %% [markdown]
# ---
# ### ✍️ 문제 1-2. 요청 승인 처리하기
#
# **설명**
# status를 approved로 바꾸고, approver 이름표에 hr_manager 를 새로 넣으세요.
#
# **만들 것**
# ① status 바꾸기 ② approver 새로 넣기 ③ request 출력
#
# **나와야 하는 결과**
# ```
# {'id': 'req-1002', 'user': 'lee02', 'status': 'approved', 'approver': 'hr_manager'}
# ```
#
# > 정답과 해설은 교재의 같은 번호에서 확인하세요.

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)
request = {"id": "req-1002", "user": "lee02", "status": "reviewing"}

# 여기에 직접 작성 👇

# %% [markdown]
# ---
# ### ✍️ 문제 1-3. 어떤 에러가 날까 (직접 실행해 확인)
#
# **설명**
# 아래를 실행하면 무엇이 나오고, '검사 완료'는 출력될지 눈으로 확인하세요.
#
# **만들 것**
# 그대로 실행해 결과 관찰 (KeyError 로 멈추는지)
#
# **나와야 하는 결과**
# ```
# KeyError: 'ip'  (그리고 '검사 완료'는 안 나옴)
# ```
#
# > 정답과 해설은 교재의 같은 번호에서 확인하세요.

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)
log = {"user": "kim01", "result": "fail"}
print(log["ip"])
print("검사 완료")

# 여기에 직접 작성 👇

# %% [markdown]
# ---
# ### ✍️ 문제 1-4. 멈추지 않게 고치기
#
# **설명**
# 1-3 코드가 멈추지 않도록 가운데 줄을 .get() 으로 바꾸세요.
#
# **만들 것**
# log 의 ip 를 .get() 으로 꺼내 출력 + '검사 완료' 출력
#
# **나와야 하는 결과**
# ```
# None\n검사 완료
# ```
#
# > 정답과 해설은 교재의 같은 번호에서 확인하세요.

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)
log = {"user": "kim01", "result": "fail"}

# 여기에 직접 작성 👇

# %% [markdown]
# ---
# ### ✍️ 문제 1-5. 로그인 실패 횟수 세기
#
# **설명**
# fail_count 가 없으면 0회로 보고, 거기에 1을 더해 출력하세요.
#
# **만들 것**
# fail_count 를 없으면 0으로 치고 +1 해서 출력
#
# **나와야 하는 결과**
# ```
# 1
# ```
#
# > 정답과 해설은 교재의 같은 번호에서 확인하세요.

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)
account = {"user": "park03", "dept": "sales"}

# 여기에 직접 작성 👇

# %% [markdown]
# ---
# ### ✍️ 문제 1-6. 승인자 배정 여부 확인
#
# **설명**
# approver 가 있으면 '승인자: (이름)', 없으면 '승인자 미배정' 을 출력하세요.
#
# **만들 것**
# in 또는 .get() 으로 승인자 유무 판단해 출력
#
# **나와야 하는 결과**
# ```
# 승인자 미배정
# ```
#
# > 정답과 해설은 교재의 같은 번호에서 확인하세요.

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)
request = {"id": "req-1003", "user": "choi04", "status": "requested"}

# 여기에 직접 작성 👇

# %% [markdown]
# ---
# ### ✍️ 문제 1-7. 요청 내역 보기 좋게 출력
#
# **설명**
# 요청의 모든 항목을 '이름표: 값' 형태로 한 줄씩 출력하세요.
#
# **만들 것**
# .items() 로 훑어 한 줄씩 출력
#
# **나와야 하는 결과**
# ```
# id: req-1004\nuser: jung05\nsystem: hr_system
# ```
#
# > 정답과 해설은 교재의 같은 번호에서 확인하세요.

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)
request = {"id": "req-1004", "user": "jung05", "system": "hr_system"}

# 여기에 직접 작성 👇

# %% [markdown]
# ---
# ### ✍️ 문제 1-8. 로그에서 IP 꺼내기 (상자 안의 상자)
#
# **설명**
# 이벤트의 detail 안에 있는 접속 IP만 출력하세요.
#
# **만들 것**
# detail 안의 ip 를 출력하는 한 줄
#
# **나와야 하는 결과**
# ```
# 192.168.0.77
# ```
#
# > 정답과 해설은 교재의 같은 번호에서 확인하세요.

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)
event = {"user": "lee02", "event_type": "login_failed",
         "detail": {"ip": "192.168.0.77", "device": "mobile"}}

# 여기에 직접 작성 👇

# %% [markdown]
# ---
# ### ✍️ 문제 1-9. detail 이 통째로 없는 로그 (⭐ 마지막 관문)
#
# **설명**
# detail 자체가 없어도 멈추지 않고 '알수없음' 이 나오게 하세요.
#
# **만들 것**
# .get() 을 두 번 이어 안전하게 ip 꺼내기 (기본값에 주의)
#
# **나와야 하는 결과**
# ```
# 알수없음
# ```
#
# > 정답과 해설은 교재의 같은 번호에서 확인하세요.

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)
event = {"user": "park03", "event_type": "logout"}

# 여기에 직접 작성 👇

# %% [markdown]
# ---
# ## 다음 층
# 1층을 다 풀었으면 교재의 **✅ 1층 통과 체크리스트**로 스스로 점검한 뒤 **2층(리스트 + .append())** 으로 갑니다.
